# %%
import pickle
import numpy as np
import json
import ast

# %%
gold_goals_file = open("deep_dialog/data/user_goals_all_turns_template.p", "rb")
gold_goals = pickle.load(gold_goals_file)

# %%
bullshit_file = open("../../DS-TC-RL/parser/goals.json.p")

# %%
bs_data = pickle.load(bullshit_file)

# %%
bs_data
# Out:
# [{'diaact': 'request',
#   'inform_slots': {'destination1': 'Mannland',
#    'flexible': True,
#    'flightDate1': '2016-11-01T07:41:42.691Z',
#    'flightDate2': '2017-07-19T06:23:11.886Z',
#    'origin1': 'East Jordyn',
#    'travelers': 1},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'destination1': 'Lisettehaven',
#    'flexible': True,
#    'flightDate1': '2017-05-08T05:45:55.457Z',
#    'flightDate2': '2018-05-30T08:40:01.279Z',
#    'origin1': 'Devinchester',
#    'travelers': 4},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'destination1': 'Danielberg',
#    'flexible': True,
#    'flightDate1': '2016-06-09T00:00:12.712Z',
#    'flightDate2': '2017-08-09T15:28:46.178Z',
#    'origin1': 'Loyalhaven',
#    'travelers': 3},
#   'request_slots': {}},
#  {'diaact': 'request',
#   'inform_slots': {'destination1': 'East Clifford',
#    'flexible': False,
#    'flightDate1': '2016-10-16T12:05:52.248Z',
# ...
